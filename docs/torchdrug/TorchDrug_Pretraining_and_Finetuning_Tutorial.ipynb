# %% [markdown]
# <a href="https://colab.research.google.com/github/kadeng/colab_tutorials/blob/master/docs/torchdrug/TorchDrug_Pretraining_and_Finetuning_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install ninja-build
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   ninja-build
# 0 upgraded, 1 newly installed, 0 to remove and 42 not upgraded.
# Need to get 93.3 kB of archives.
# After this operation, 296 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 ninja-build amd64 1.8.2-1 [93.3 kB]
# Fetched 93.3 kB in 1s (114 kB/s)
# Selecting previously unselected package ninja-build.
# (Reading database ... 155629 files and directories currently installed.)
# Preparing to unpack .../ninja-build_1.8.2-1_amd64.deb ...
# Unpacking ninja-build (1.8.2-1) ...
# Setting up ninja-build (1.8.2-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
import os
import sys
import torch
if not os.path.exists("/gdrive/MyDrive/colab/pipenv"):
  from google.colab import drive
  drive.mount('/gdrive')
if not os.path.exists("/gdrive/MyDrive/colab/pipenv"):
  print("Installing packages..")
  os.path.makedirs("/gdrive/MyDrive/colab/pipenv", exist_ok=True)
  os.environ["TORCH_VERSION"] = torch.__version__
  # !pip install -t /gdrive/MyDrive/colab/pipenv/ torch-scatter -f https://pytorch-geometric.com/whl/torch-$TORCH_VERSION.html
  # !pip install -t /gdrive/MyDrive/colab/pipenv/ git+https://github.com/DeepGraphLearning/torchdrug
  # !pip install -t /gdrive/MyDrive/colab/pipenv/ ninja
  
  print("Done installing packages")
sys.path.insert(0, "/gdrive/MyDrive/colab/pipenv")
print("OK")
# Out:
# Mounted at /gdrive
# OK

# %% [markdown]
# ### Introduction
#
# In many drug discovery tasks, it is costly in both time and money to collect labeled data. As a solution, self-supervised pretraining is introduced to learn molecular representations from massive unlabeled data.
#
# In this tutorial, we will demonstrate how to pretrain a graph neural network on molecules, and how to finetune the model on downstream tasks.
#
# ### Manual Steps
#
# 0.   Get your own copy of this file via "File > Save a copy in Drive...",
# 1.   Set the runtime to **GPU** via "Runtime > Change runtime type..."
#
# ### Colab Tutorials
#
# #### Quick Start
# 1. [Basic Usage and Pipeline](https://colab.research.google.com/drive/1Tbnr1Fog_YjkqU1MOhcVLuxqZ4DC-c8-#forceEdit=true&sandboxMode=true)
#
# #### Drug Discovery Tasks
# 1. [Property Prediction](https://colab.research.google.com/drive/1sb2w3evdEWm-GYo28RksvzJ74p63xHMn?usp=sharing#forceEdit=true&sandboxMode=true)
# 2. [Pretrained Molecular Representations](https://colab.research.google.com/drive/10faCIVIfln20f2h1oQk2UrXiAMqZKLoW?usp=sharing#forceEdit=true&sandboxMode=true)
# 3. [De Novo Molecule Design](https://colab.research.google.com/drive/1JEMiMvSBuqCuzzREYpviNZZRVOYsgivA?usp=sharing#forceEdit=true&sandboxMode=true)
# 4. [Retrosynthesis](https://colab.research.google.com/drive/1IH1hk7K3MaxAEe5m6CFY7Eyej3RuiEL1?usp=sharing#forceEdit=true&sandboxMode=true)
# 5. [Knowledge Graph Reasoning](https://colab.research.google.com/drive/1-sjqQZhYrGM0HiMuaqXOiqhDNlJi7g_I?usp=sharing#forceEdit=true&sandboxMode=true)

# %% [markdown]
# # Self-Supervised Pretraining
#
# Pretraining is an effective approach to transfer learning in Graph Neural Networks for graph-level property prediction. Here we focus on pretraining GNNs via different self-supervised strategies. These methods typically construct unsupervised loss functions based on structural information in molecules.
#
# For illustrative purpose, we only use the ClinTox dataset in this tutorial, which is much smaller than the standard pretraining datasets. For real applications, we suggest using larger datasets like ZINC2M.

# %% [markdown]
# ## Infograph
#
# InfoGraph (IG) proposes to maximize the mutual information between the graph-level and node-level representations. It learns the model by distinguishing whether a node-graph pair comes from a single graph or two different graphs. The following figure illustrates the high-level idea of InfoGraph.

# %% [markdown]
# ![infograph.png](https://raw.githubusercontent.com/DeepGraphLearning/torchdrug/master/asset/model/infograph.png)

# %% [markdown]
# We use GIN as our graph represenation model, and wrap it with InfoGraph.

# %%
import torch
from torch import nn
from torch.utils import data as torch_data

from torchdrug import core, datasets, tasks, models

dataset = datasets.ClinTox("/gdrive/MyDrive/colab/molecule-datasets/", node_feature="pretrain",
                           edge_feature="pretrain")

gin_model = models.GIN(input_dim=dataset.node_feature_dim,
                       hidden_dims=[300, 300, 300, 300, 300],
                       edge_input_dim=dataset.edge_feature_dim,
                       batch_norm=True, readout="mean")
model = models.InfoGraph(gin_model, separate_model=False)

task = tasks.Unsupervised(model)
optimizer = torch.optim.Adam(task.parameters(), lr=1e-3)
solver = core.Engine(task, dataset, None, None, optimizer, gpus=[0], batch_size=256)

solver.train(num_epoch=10)
solver.save("clintox_gin_infograph.pth")
# Out:
# Loading /gdrive/MyDrive/colab/molecule-datasets/clintox.csv: 100%|██████████| 1485/1485 [00:00<00:00, 87951.39it/s]
# Constructing molecules from SMILES:   0%|          | 0/1484 [00:00<?, ?it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `*`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:   0%|          | 1/1484 [00:00<07:42,  3.20it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Tc`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Fe`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Al`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:   8%|▊         | 118/1484 [00:00<00:03, 368.57it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Ca`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Pt`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:  21%|██        | 312/1484 [00:00<00:01, 680.21it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Bi`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:  90%|████████▉ | 1329/1484 [00:01<00:00, 665.74it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Au`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Tl`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Cr`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Mn`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:  95%|█████████▌| 1415/1484 [00:02<00:00, 714.21it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Hg`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `As`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Ti`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES: 100%|██████████| 1484/1484 [00:02<00:00, 689.04it/s]
# 13:42:10   {'batch_size': 256,
#  'class': 'core.Engine',
#  'gpus': [0],
#  'gradient_interval': 1,
#  'log_interval': 100,
#  'logger': 'logging',
#  'num_worker': 0,
#  'optimizer': {'amsgrad': False,
#                'betas': (0.9, 0.999),
#                'class': 'optim.Adam',
#                'eps': 1e-08,
#                'lr': 0.001,
#                'maximize': False,
#                'weight_decay': 0},
#  'scheduler': None,
#  'task': Unsupervised(
#   (model): InfoGraph(
#     (model): GraphIsomorphismNetwork(
#       (layers): ModuleList(
#         (0): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=22, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=22, bias=True)
#         )
#         (1): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=300, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=300, bias=True)
#         )
#         (2): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=300, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=300, bias=True)
#         )
#         (3): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=300, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=300, bias=True)
#         )
#         (4): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=300, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=300, bias=True)
#         )
#       )
#       (readout): MeanReadout()
#     )
#     (unsupervised_model): GraphIsomorphismNetwork(
#       (layers): ModuleList(
#         (0): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=22, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=22, bias=True)
#         )
#         (1): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=300, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=300, bias=True)
#         )
#         (2): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=300, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=300, bias=True)
#         )
#         (3): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=300, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=300, bias=True)
#         )
#         (4): GraphIsomorphismConv(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (mlp): MultiLayerPerceptron(
#             (layers): ModuleList(
#               (0): Linear(in_features=300, out_features=300, bias=True)
#               (1): Linear(in_features=300, out_features=300, bias=True)
#             )
#           )
#           (edge_linear): Linear(in_features=11, out_features=300, bias=True)
#         )
#       )
#       (readout): MeanReadout()
#     )
#     (unsupervised_mi): MutualInformation(
#       (x_mlp): MultiLayerPerceptron(
#         (layers): ModuleList(
#           (0): Linear(in_features=300, out_features=300, bias=True)
#           (1): Linear(in_features=300, out_features=300, bias=True)
#         )
#       )
#       (y_mlp): MultiLayerPerceptron(
#         (layers): ModuleList(
#           (0): Linear(in_features=300, out_features=300, bias=True)
#           (1): Linear(in_features=300, out_features=300, bias=True)
#         )
#       )
#     )
#   )
# ),
#  'test_set': None,
#  'train_set': {'class': 'datasets.ClinTox',
#                'edge_feature': 'pretrain',
#                'node_feature': 'pretrain',
#                'path': '/gdrive/MyDrive/colab/molecule-datasets/',
#                'verbose': 1},
#  'valid_set': None}
# 13:42:10   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:10   Epoch 0 begin
# 13:42:26   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:26   graph-node mutual information: -0.0622405
# 13:42:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:27   Epoch 0 end
# 13:42:27   duration: 16.08 secs
# 13:42:27   speed: 0.37 batch / sec
# 13:42:27   ETA: 2.41 mins
# 13:42:27   max GPU memory: 342.7 MiB
# 13:42:27   ------------------------------
# 13:42:27   average graph-node mutual information: -0.240288
# 13:42:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:27   Epoch 1 begin
# 13:42:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:27   Epoch 1 end
# 13:42:27   duration: 0.29 secs
# 13:42:27   speed: 20.53 batch / sec
# 13:42:27   ETA: 1.09 mins
# 13:42:27   max GPU memory: 338.8 MiB
# 13:42:27   ------------------------------
# 13:42:27   average graph-node mutual information: 0.180565
# 13:42:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:27   Epoch 2 begin
# 13:42:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:27   Epoch 2 end
# 13:42:27   duration: 0.29 secs
# 13:42:27   speed: 20.60 batch / sec
# 13:42:27   ETA: 38.88 secs
# 13:42:27   max GPU memory: 342.6 MiB
# 13:42:27   ------------------------------
# 13:42:27   average graph-node mutual information: 0.317389
# 13:42:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:27   Epoch 3 begin
# 13:42:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:27   Epoch 3 end
# 13:42:27   duration: 0.30 secs
# 13:42:27   speed: 20.30 batch / sec
# 13:42:27   ETA: 25.44 secs
# 13:42:27   max GPU memory: 350.4 MiB
# 13:42:27   ------------------------------
# 13:42:27   average graph-node mutual information: 0.454458
# 13:42:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:27   Epoch 4 begin
# 13:42:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:28   Epoch 4 end
# 13:42:28   duration: 0.29 secs
# 13:42:28   speed: 21.03 batch / sec
# 13:42:28   ETA: 17.24 secs
# 13:42:28   max GPU memory: 332.5 MiB
# 13:42:28   ------------------------------
# 13:42:28   average graph-node mutual information: 0.575775
# 13:42:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:28   Epoch 5 begin
# 13:42:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:28   Epoch 5 end
# 13:42:28   duration: 0.29 secs
# 13:42:28   speed: 20.49 batch / sec
# 13:42:28   ETA: 11.69 secs
# 13:42:28   max GPU memory: 347.1 MiB
# 13:42:28   ------------------------------
# 13:42:28   average graph-node mutual information: 0.660434
# 13:42:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:28   Epoch 6 begin
# 13:42:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:28   Epoch 6 end
# 13:42:28   duration: 0.29 secs
# 13:42:28   speed: 20.36 batch / sec
# 13:42:28   ETA: 7.64 secs
# 13:42:28   max GPU memory: 343.3 MiB
# 13:42:28   ------------------------------
# 13:42:28   average graph-node mutual information: 0.728271
# 13:42:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:28   Epoch 7 begin
# 13:42:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:29   Epoch 7 end
# 13:42:29   duration: 0.29 secs
# 13:42:29   speed: 20.49 batch / sec
# 13:42:29   ETA: 4.53 secs
# 13:42:29   max GPU memory: 342.3 MiB
# 13:42:29   ------------------------------
# 13:42:29   average graph-node mutual information: 0.785378
# 13:42:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:29   Epoch 8 begin
# 13:42:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:29   Epoch 8 end
# 13:42:29   duration: 0.29 secs
# 13:42:29   speed: 20.73 batch / sec
# 13:42:29   ETA: 2.05 secs
# 13:42:29   max GPU memory: 332.0 MiB
# 13:42:29   ------------------------------
# 13:42:29   average graph-node mutual information: 0.829703
# 13:42:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:29   Epoch 9 begin
# 13:42:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:42:29   Epoch 9 end
# 13:42:29   duration: 0.29 secs
# 13:42:29   speed: 20.75 batch / sec
# 13:42:29   ETA: 0.00 secs
# 13:42:29   max GPU memory: 342.9 MiB
# 13:42:29   ------------------------------
# 13:42:29   average graph-node mutual information: 0.875407
# 13:42:29   Save checkpoint to clintox_gin_infograph.pth

# %%
# !mkdir -p /gdrive/MyDrive/colab/molecule-models/
solver.save("/gdrive/MyDrive/colab/molecule-models/clintox_gin_infograph.pth")
# Out:
# 13:43:42   Save checkpoint to /gdrive/MyDrive/colab/molecule-models/clintox_gin_infograph.pth

# %% [markdown]
# ## Attribute Masking
#
# The aim of Attribute Masking (AM) is to capture domain knowledge by learning the regularities of the node/edge attributes distributed over graph structure. The high-level idea is to predict atom types in molecular graphs from randomly masked node features.

# %% [markdown]
# ![attrmasking.png](https://raw.githubusercontent.com/DeepGraphLearning/torchdrug/master/asset/model/attribute_masking.png)

# %% [markdown]
# Again, we use GIN as our graph representation model.

# %%
import torch
from torch import nn
from torch.utils import data as torch_data

from torchdrug import core, datasets, tasks, models

dataset = datasets.ClinTox("/gdrive/MyDrive/colab/molecule-datasets/", node_feature="pretrain",
                           edge_feature="pretrain")

model = models.GIN(input_dim=dataset.node_feature_dim,
                   hidden_dims=[300, 300, 300, 300, 300],
                   edge_input_dim=dataset.edge_feature_dim,
                   batch_norm=True, readout="mean")
task = tasks.AttributeMasking(model, mask_rate=0.15)

optimizer = torch.optim.Adam(task.parameters(), lr=1e-3)
solver = core.Engine(task, dataset, None, None, optimizer, gpus=[0], batch_size=256)

solver.train(num_epoch=10)
solver.save("/gdrive/MyDrive/colab/molecule-models/clintox_gin_attributemasking.pth")
# Out:
# Loading /gdrive/MyDrive/colab/molecule-datasets/clintox.csv: 100%|██████████| 1485/1485 [00:00<00:00, 94021.40it/s]
# Constructing molecules from SMILES:   0%|          | 0/1484 [00:00<?, ?it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `*`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Tc`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Fe`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Al`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:   8%|▊         | 118/1484 [00:00<00:01, 1175.02it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Ca`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Pt`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:  16%|█▌        | 236/1484 [00:00<00:01, 1012.09it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Bi`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:  87%|████████▋ | 1297/1484 [00:01<00:00, 786.42it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Au`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Tl`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Cr`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Mn`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:  93%|█████████▎| 1380/1484 [00:01<00:00, 794.86it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Hg`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES:  99%|█████████▊| 1465/1484 [00:01<00:00, 810.87it/s]/gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `As`
#   warnings.warn("Unknown value `%s`" % x)
# /gdrive/MyDrive/colab/pipenv/torchdrug/data/feature.py:37: UserWarning: Unknown value `Ti`
#   warnings.warn("Unknown value `%s`" % x)
# Constructing molecules from SMILES: 100%|██████████| 1484/1484 [00:01<00:00, 841.17it/s]
# 13:48:04   {'batch_size': 256,
#  'class': 'core.Engine',
#  'gpus': [0],
#  'gradient_interval': 1,
#  'log_interval': 100,
#  'logger': 'logging',
#  'num_worker': 0,
#  'optimizer': {'amsgrad': False,
#                'betas': (0.9, 0.999),
#                'class': 'optim.Adam',
#                'eps': 1e-08,
#                'lr': 0.001,
#                'maximize': False,
#                'weight_decay': 0},
#  'scheduler': None,
#  'task': {'class': 'tasks.AttributeMasking',
#           'mask_rate': 0.15,
#           'model': {'activation': 'relu',
#                     'batch_norm': True,
#                     'class': 'models.GIN',
#                     'concat_hidden': False,
#                     'edge_input_dim': 11,
#                     'eps': 0,
#                     'hidden_dims': [300, 300, 300, 300, 300],
#                     'input_dim': 22,
#                     'learn_eps': False,
#                     'num_mlp_layer': 2,
#                     'readout': 'mean',
#                     'short_cut': False},
#           'num_mlp_layer': 2},
#  'test_set': None,
#  'train_set': {'class': 'datasets.ClinTox',
#                'edge_feature': 'pretrain',
#                'node_feature': 'pretrain',
#                'path': '/gdrive/MyDrive/colab/molecule-datasets/',
#                'verbose': 1},
#  'valid_set': None}
# 13:48:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:04   Epoch 0 begin
# 13:48:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:04   accuracy: 0
# 13:48:04   cross entropy: 4.8936
# 13:48:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:04   Epoch 0 end
# 13:48:04   duration: 0.28 secs
# 13:48:04   speed: 21.34 batch / sec
# 13:48:04   ETA: 2.53 secs
# 13:48:04   max GPU memory: 253.7 MiB
# 13:48:04   ------------------------------
# 13:48:04   average accuracy: 0.571284
# 13:48:04   average cross entropy: 3.52324
# 13:48:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:04   Epoch 1 begin
# 13:48:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:04   Epoch 1 end
# 13:48:04   duration: 0.27 secs
# 13:48:04   speed: 22.25 batch / sec
# 13:48:04   ETA: 2.20 secs
# 13:48:04   max GPU memory: 251.3 MiB
# 13:48:04   ------------------------------
# 13:48:04   average accuracy: 0.710235
# 13:48:04   average cross entropy: 1.35047
# 13:48:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:04   Epoch 2 begin
# 13:48:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:04   Epoch 2 end
# 13:48:04   duration: 0.25 secs
# 13:48:04   speed: 23.81 batch / sec
# 13:48:04   ETA: 1.87 secs
# 13:48:04   max GPU memory: 253.6 MiB
# 13:48:04   ------------------------------
# 13:48:04   average accuracy: 0.744071
# 13:48:04   average cross entropy: 0.803622
# 13:48:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:04   Epoch 3 begin
# 13:48:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:05   Epoch 3 end
# 13:48:05   duration: 0.26 secs
# 13:48:05   speed: 23.35 batch / sec
# 13:48:05   ETA: 1.59 secs
# 13:48:05   max GPU memory: 259.9 MiB
# 13:48:05   ------------------------------
# 13:48:05   average accuracy: 0.788689
# 13:48:05   average cross entropy: 0.646642
# 13:48:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:05   Epoch 4 begin
# 13:48:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:05   Epoch 4 end
# 13:48:05   duration: 0.26 secs
# 13:48:05   speed: 23.26 batch / sec
# 13:48:05   ETA: 1.32 secs
# 13:48:05   max GPU memory: 247.1 MiB
# 13:48:05   ------------------------------
# 13:48:05   average accuracy: 0.797696
# 13:48:05   average cross entropy: 0.606427
# 13:48:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:05   Epoch 5 begin
# 13:48:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:05   Epoch 5 end
# 13:48:05   duration: 0.25 secs
# 13:48:05   speed: 23.73 batch / sec
# 13:48:05   ETA: 1.05 secs
# 13:48:05   max GPU memory: 257.4 MiB
# 13:48:05   ------------------------------
# 13:48:05   average accuracy: 0.796022
# 13:48:05   average cross entropy: 0.549602
# 13:48:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:05   Epoch 6 begin
# 13:48:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:05   Epoch 6 end
# 13:48:05   duration: 0.26 secs
# 13:48:05   speed: 23.48 batch / sec
# 13:48:05   ETA: 0.78 secs
# 13:48:05   max GPU memory: 254.3 MiB
# 13:48:05   ------------------------------
# 13:48:05   average accuracy: 0.832889
# 13:48:05   average cross entropy: 0.505042
# 13:48:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:05   Epoch 7 begin
# 13:48:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:06   Epoch 7 end
# 13:48:06   duration: 0.25 secs
# 13:48:06   speed: 23.60 batch / sec
# 13:48:06   ETA: 0.52 secs
# 13:48:06   max GPU memory: 253.4 MiB
# 13:48:06   ------------------------------
# 13:48:06   average accuracy: 0.828352
# 13:48:06   average cross entropy: 0.485729
# 13:48:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:06   Epoch 8 begin
# 13:48:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:06   Epoch 8 end
# 13:48:06   duration: 0.26 secs
# 13:48:06   speed: 23.37 batch / sec
# 13:48:06   ETA: 0.26 secs
# 13:48:06   max GPU memory: 246.8 MiB
# 13:48:06   ------------------------------
# 13:48:06   average accuracy: 0.840395
# 13:48:06   average cross entropy: 0.467423
# 13:48:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:06   Epoch 9 begin
# 13:48:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 13:48:06   Epoch 9 end
# 13:48:06   duration: 0.26 secs
# 13:48:06   speed: 23.49 batch / sec
# 13:48:06   ETA: 0.00 secs
# 13:48:06   max GPU memory: 253.9 MiB
# 13:48:06   ------------------------------
# 13:48:06   average accuracy: 0.842921
# 13:48:06   average cross entropy: 0.456914
# 13:48:06   Save checkpoint to /gdrive/MyDrive/colab/molecule-models/clintox_gin_attributemasking.pth

# %% [markdown]
# # Finetune on Labeled Datasets
# When the GNN pre-training is finished, we can finetune the pre-trained GNN model on downstream tasks. Here we use BACE dataset for illustration, which contains 1,513 molecules with binding affinity results a set of inhibitors of human 𝛽-secretase 1(BACE-1).
#
# First, we download the BACE dataset and split it into training, validation and test sets. Note that we need to set the node and edge feature in the dataset as pretrain in order to make it compatible with the pretrained model.

# %%
from torchdrug import data

dataset = datasets.BACE("~/molecule-datasets/",
                        node_feature="pretrain", edge_feature="pretrain")
lengths = [int(0.8 * len(dataset)), int(0.1 * len(dataset))]
lengths += [len(dataset) - sum(lengths)]
train_set, valid_set, test_set = data.ordered_scaffold_split(dataset, lengths)
# Out:
# 01:27:18   Downloading http://deepchem.io.s3-website-us-west-1.amazonaws.com/datasets/bace.csv to /root/molecule-datasets/bace.csv
# Loading /root/molecule-datasets/bace.csv: 100%|██████████| 1514/1514 [00:00<00:00, 7727.68it/s]
# Constructing molecules from SMILES: 100%|██████████| 1513/1513 [00:03<00:00, 463.58it/s]

# %% [markdown]
# Then, we define the same model as the pre-training stage and set up the optimizer and solver for our downstream task. The only difference here is that we use PropertyPrediction task to support supervised learning.

# %%
model = models.GIN(input_dim=dataset.node_feature_dim,
                hidden_dims=[300, 300, 300, 300, 300],
                edge_input_dim=dataset.edge_feature_dim,
                batch_norm=True, readout="mean")
task = tasks.PropertyPrediction(model, task=dataset.tasks,
                                criterion="bce", metric=("auprc", "auroc"))

optimizer = torch.optim.Adam(task.parameters(), lr=1e-3)
solver = core.Engine(task, train_set, valid_set, test_set, optimizer,
                     gpus=[0], batch_size=256)
# Out:
# 01:27:54   Preprocess training set

# %% [markdown]
# Now we can load our pretrained model and finetune it on downstream datasets.

# %%
checkpoint = torch.load("clintox_gin_infograph.pth")["model"]
task.load_state_dict(checkpoint, strict=False)

solver.train(num_epoch=100)
solver.evaluate("valid")
# Out:
# 01:28:43   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:43   Epoch 0 begin
# 01:28:43   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:43   binary cross entropy: 0.689819
# 01:28:44   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:44   Epoch 0 end
# 01:28:44   duration: 49.59 secs
# 01:28:44   speed: 0.10 batch / sec
# 01:28:44   ETA: 1.36 hours
# 01:28:44   max GPU memory: 300.2 MiB
# 01:28:44   ------------------------------
# 01:28:44   average binary cross entropy: 0.611645
# 01:28:44   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:44   Epoch 1 begin
# 01:28:44   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:44   Epoch 1 end
# 01:28:44   duration: 0.52 secs
# 01:28:44   speed: 9.65 batch / sec
# 01:28:44   ETA: 40.92 mins
# 01:28:44   max GPU memory: 300.4 MiB
# 01:28:44   ------------------------------
# 01:28:45   average binary cross entropy: 0.530311
# 01:28:45   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:45   Epoch 2 begin
# 01:28:45   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:45   Epoch 2 end
# 01:28:45   duration: 0.49 secs
# 01:28:45   speed: 10.27 batch / sec
# 01:28:45   ETA: 27.27 mins
# 01:28:45   max GPU memory: 297.0 MiB
# 01:28:45   ------------------------------
# 01:28:45   average binary cross entropy: 0.462999
# 01:28:45   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:45   Epoch 3 begin
# 01:28:45   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:45   Epoch 3 end
# 01:28:45   duration: 0.48 secs
# 01:28:45   speed: 10.43 batch / sec
# 01:28:45   ETA: 20.43 mins
# 01:28:45   max GPU memory: 297.2 MiB
# 01:28:45   ------------------------------
# 01:28:45   average binary cross entropy: 0.431632
# 01:28:45   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:45   Epoch 4 begin
# 01:28:46   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:46   Epoch 4 end
# 01:28:46   duration: 0.48 secs
# 01:28:46   speed: 10.47 batch / sec
# 01:28:46   ETA: 16.33 mins
# 01:28:46   max GPU memory: 296.7 MiB
# 01:28:46   ------------------------------
# 01:28:46   average binary cross entropy: 0.39606
# 01:28:46   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:46   Epoch 5 begin
# 01:28:46   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:46   Epoch 5 end
# 01:28:46   duration: 0.48 secs
# 01:28:46   speed: 10.42 batch / sec
# 01:28:46   ETA: 13.59 mins
# 01:28:46   max GPU memory: 297.8 MiB
# 01:28:46   ------------------------------
# 01:28:46   average binary cross entropy: 0.378273
# 01:28:46   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:46   Epoch 6 begin
# 01:28:47   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:47   Epoch 6 end
# 01:28:47   duration: 0.48 secs
# 01:28:47   speed: 10.49 batch / sec
# 01:28:47   ETA: 11.63 mins
# 01:28:47   max GPU memory: 301.1 MiB
# 01:28:47   ------------------------------
# 01:28:47   average binary cross entropy: 0.371808
# 01:28:47   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:47   Epoch 7 begin
# 01:28:47   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:47   Epoch 7 end
# 01:28:47   duration: 0.48 secs
# 01:28:47   speed: 10.39 batch / sec
# 01:28:47   ETA: 10.16 mins
# 01:28:47   max GPU memory: 296.6 MiB
# 01:28:47   ------------------------------
# 01:28:47   average binary cross entropy: 0.358251
# 01:28:47   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:47   Epoch 8 begin
# 01:28:48   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:48   Epoch 8 end
# 01:28:48   duration: 0.48 secs
# 01:28:48   speed: 10.51 batch / sec
# 01:28:48   ETA: 9.01 mins
# 01:28:48   max GPU memory: 298.2 MiB
# 01:28:48   ------------------------------
# 01:28:48   average binary cross entropy: 0.347047
# 01:28:48   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:48   Epoch 9 begin
# 01:28:48   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:48   Epoch 9 end
# 01:28:48   duration: 0.49 secs
# 01:28:48   speed: 10.29 batch / sec
# 01:28:48   ETA: 8.09 mins
# 01:28:48   max GPU memory: 300.0 MiB
# 01:28:48   ------------------------------
# 01:28:48   average binary cross entropy: 0.341435
# 01:28:48   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:48   Epoch 10 begin
# 01:28:49   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:49   Epoch 10 end
# 01:28:49   duration: 0.48 secs
# 01:28:49   speed: 10.48 batch / sec
# 01:28:49   ETA: 7.34 mins
# 01:28:49   max GPU memory: 296.6 MiB
# 01:28:49   ------------------------------
# 01:28:49   average binary cross entropy: 0.345899
# 01:28:49   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:49   Epoch 11 begin
# 01:28:49   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:49   Epoch 11 end
# 01:28:49   duration: 0.48 secs
# 01:28:49   speed: 10.35 batch / sec
# 01:28:49   ETA: 6.71 mins
# 01:28:49   max GPU memory: 297.1 MiB
# 01:28:49   ------------------------------
# 01:28:49   average binary cross entropy: 0.316186
# 01:28:49   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:49   Epoch 12 begin
# 01:28:50   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:50   Epoch 12 end
# 01:28:50   duration: 0.48 secs
# 01:28:50   speed: 10.46 batch / sec
# 01:28:50   ETA: 6.18 mins
# 01:28:50   max GPU memory: 296.9 MiB
# 01:28:50   ------------------------------
# 01:28:50   average binary cross entropy: 0.322061
# 01:28:50   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:50   Epoch 13 begin
# 01:28:50   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:50   Epoch 13 end
# 01:28:50   duration: 0.47 secs
# 01:28:50   speed: 10.65 batch / sec
# 01:28:50   ETA: 5.72 mins
# 01:28:50   max GPU memory: 297.9 MiB
# 01:28:50   ------------------------------
# 01:28:50   average binary cross entropy: 0.311287
# 01:28:50   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:50   Epoch 14 begin
# 01:28:51   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:51   Epoch 14 end
# 01:28:51   duration: 0.50 secs
# 01:28:51   speed: 10.01 batch / sec
# 01:28:51   ETA: 5.32 mins
# 01:28:51   max GPU memory: 296.8 MiB
# 01:28:51   ------------------------------
# 01:28:51   average binary cross entropy: 0.298982
# 01:28:51   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:51   Epoch 15 begin
# 01:28:51   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:51   Epoch 15 end
# 01:28:51   duration: 0.48 secs
# 01:28:51   speed: 10.50 batch / sec
# 01:28:51   ETA: 4.97 mins
# 01:28:51   max GPU memory: 308.9 MiB
# 01:28:51   ------------------------------
# 01:28:51   average binary cross entropy: 0.29646
# 01:28:51   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:51   Epoch 16 begin
# 01:28:52   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:52   Epoch 16 end
# 01:28:52   duration: 0.48 secs
# 01:28:52   speed: 10.42 batch / sec
# 01:28:52   ETA: 4.66 mins
# 01:28:52   max GPU memory: 297.8 MiB
# 01:28:52   ------------------------------
# 01:28:52   average binary cross entropy: 0.283558
# 01:28:52   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:52   Epoch 17 begin
# 01:28:52   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:52   Epoch 17 end
# 01:28:52   duration: 0.47 secs
# 01:28:52   speed: 10.58 batch / sec
# 01:28:52   ETA: 4.39 mins
# 01:28:52   max GPU memory: 297.0 MiB
# 01:28:52   ------------------------------
# 01:28:52   average binary cross entropy: 0.297868
# 01:28:52   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:52   Epoch 18 begin
# 01:28:53   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:53   Epoch 18 end
# 01:28:53   duration: 0.48 secs
# 01:28:53   speed: 10.37 batch / sec
# 01:28:53   ETA: 4.14 mins
# 01:28:53   max GPU memory: 300.8 MiB
# 01:28:53   ------------------------------
# 01:28:53   average binary cross entropy: 0.289506
# 01:28:53   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:53   Epoch 19 begin
# 01:28:53   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:53   Epoch 19 end
# 01:28:53   duration: 0.49 secs
# 01:28:53   speed: 10.23 batch / sec
# 01:28:53   ETA: 3.92 mins
# 01:28:53   max GPU memory: 296.4 MiB
# 01:28:53   ------------------------------
# 01:28:53   average binary cross entropy: 0.274656
# 01:28:53   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:53   Epoch 20 begin
# 01:28:53   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:53   binary cross entropy: 0.254819
# 01:28:54   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:54   Epoch 20 end
# 01:28:54   duration: 0.49 secs
# 01:28:54   speed: 10.27 batch / sec
# 01:28:54   ETA: 3.71 mins
# 01:28:54   max GPU memory: 297.0 MiB
# 01:28:54   ------------------------------
# 01:28:54   average binary cross entropy: 0.268221
# 01:28:54   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:54   Epoch 21 begin
# 01:28:54   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:54   Epoch 21 end
# 01:28:54   duration: 0.48 secs
# 01:28:54   speed: 10.33 batch / sec
# 01:28:54   ETA: 3.53 mins
# 01:28:54   max GPU memory: 296.7 MiB
# 01:28:54   ------------------------------
# 01:28:54   average binary cross entropy: 0.259369
# 01:28:54   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:54   Epoch 22 begin
# 01:28:55   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:55   Epoch 22 end
# 01:28:55   duration: 0.49 secs
# 01:28:55   speed: 10.22 batch / sec
# 01:28:55   ETA: 3.36 mins
# 01:28:55   max GPU memory: 296.5 MiB
# 01:28:55   ------------------------------
# 01:28:55   average binary cross entropy: 0.247006
# 01:28:55   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:55   Epoch 23 begin
# 01:28:55   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:55   Epoch 23 end
# 01:28:55   duration: 0.47 secs
# 01:28:55   speed: 10.68 batch / sec
# 01:28:55   ETA: 3.20 mins
# 01:28:55   max GPU memory: 297.7 MiB
# 01:28:55   ------------------------------
# 01:28:55   average binary cross entropy: 0.25035
# 01:28:55   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:55   Epoch 24 begin
# 01:28:56   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:56   Epoch 24 end
# 01:28:56   duration: 0.49 secs
# 01:28:56   speed: 10.27 batch / sec
# 01:28:56   ETA: 3.06 mins
# 01:28:56   max GPU memory: 298.6 MiB
# 01:28:56   ------------------------------
# 01:28:56   average binary cross entropy: 0.257744
# 01:28:56   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:56   Epoch 25 begin
# 01:28:56   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:56   Epoch 25 end
# 01:28:56   duration: 0.48 secs
# 01:28:56   speed: 10.44 batch / sec
# 01:28:56   ETA: 2.92 mins
# 01:28:56   max GPU memory: 296.9 MiB
# 01:28:56   ------------------------------
# 01:28:56   average binary cross entropy: 0.250383
# 01:28:56   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:56   Epoch 26 begin
# 01:28:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:57   Epoch 26 end
# 01:28:57   duration: 0.48 secs
# 01:28:57   speed: 10.32 batch / sec
# 01:28:57   ETA: 2.80 mins
# 01:28:57   max GPU memory: 297.5 MiB
# 01:28:57   ------------------------------
# 01:28:57   average binary cross entropy: 0.229262
# 01:28:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:57   Epoch 27 begin
# 01:28:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:57   Epoch 27 end
# 01:28:57   duration: 0.47 secs
# 01:28:57   speed: 10.60 batch / sec
# 01:28:57   ETA: 2.68 mins
# 01:28:57   max GPU memory: 297.4 MiB
# 01:28:57   ------------------------------
# 01:28:57   average binary cross entropy: 0.230803
# 01:28:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:57   Epoch 28 begin
# 01:28:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:57   Epoch 28 end
# 01:28:57   duration: 0.50 secs
# 01:28:57   speed: 10.03 batch / sec
# 01:28:57   ETA: 2.58 mins
# 01:28:57   max GPU memory: 297.1 MiB
# 01:28:57   ------------------------------
# 01:28:57   average binary cross entropy: 0.230321
# 01:28:58   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:58   Epoch 29 begin
# 01:28:58   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:58   Epoch 29 end
# 01:28:58   duration: 0.48 secs
# 01:28:58   speed: 10.42 batch / sec
# 01:28:58   ETA: 2.47 mins
# 01:28:58   max GPU memory: 296.9 MiB
# 01:28:58   ------------------------------
# 01:28:58   average binary cross entropy: 0.226591
# 01:28:58   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:58   Epoch 30 begin
# 01:28:58   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:58   Epoch 30 end
# 01:28:58   duration: 0.50 secs
# 01:28:58   speed: 10.09 batch / sec
# 01:28:58   ETA: 2.38 mins
# 01:28:58   max GPU memory: 298.3 MiB
# 01:28:58   ------------------------------
# 01:28:58   average binary cross entropy: 0.246103
# 01:28:58   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:58   Epoch 31 begin
# 01:28:59   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:59   Epoch 31 end
# 01:28:59   duration: 0.48 secs
# 01:28:59   speed: 10.43 batch / sec
# 01:28:59   ETA: 2.29 mins
# 01:28:59   max GPU memory: 297.5 MiB
# 01:28:59   ------------------------------
# 01:28:59   average binary cross entropy: 0.244333
# 01:28:59   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:59   Epoch 32 begin
# 01:28:59   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:59   Epoch 32 end
# 01:28:59   duration: 0.48 secs
# 01:28:59   speed: 10.49 batch / sec
# 01:28:59   ETA: 2.20 mins
# 01:28:59   max GPU memory: 296.8 MiB
# 01:28:59   ------------------------------
# 01:28:59   average binary cross entropy: 0.224124
# 01:28:59   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:28:59   Epoch 33 begin
# 01:29:00   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:00   Epoch 33 end
# 01:29:00   duration: 0.49 secs
# 01:29:00   speed: 10.18 batch / sec
# 01:29:00   ETA: 2.12 mins
# 01:29:00   max GPU memory: 298.5 MiB
# 01:29:00   ------------------------------
# 01:29:00   average binary cross entropy: 0.233395
# 01:29:00   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:00   Epoch 34 begin
# 01:29:00   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:00   Epoch 34 end
# 01:29:00   duration: 0.48 secs
# 01:29:00   speed: 10.38 batch / sec
# 01:29:00   ETA: 2.04 mins
# 01:29:00   max GPU memory: 296.3 MiB
# 01:29:00   ------------------------------
# 01:29:00   average binary cross entropy: 0.229047
# 01:29:00   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:00   Epoch 35 begin
# 01:29:01   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:01   Epoch 35 end
# 01:29:01   duration: 0.48 secs
# 01:29:01   speed: 10.45 batch / sec
# 01:29:01   ETA: 1.97 mins
# 01:29:01   max GPU memory: 296.9 MiB
# 01:29:01   ------------------------------
# 01:29:01   average binary cross entropy: 0.212482
# 01:29:01   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:01   Epoch 36 begin
# 01:29:01   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:01   Epoch 36 end
# 01:29:01   duration: 0.47 secs
# 01:29:01   speed: 10.71 batch / sec
# 01:29:01   ETA: 1.90 mins
# 01:29:01   max GPU memory: 304.8 MiB
# 01:29:01   ------------------------------
# 01:29:01   average binary cross entropy: 0.1985
# 01:29:01   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:01   Epoch 37 begin
# 01:29:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:02   Epoch 37 end
# 01:29:02   duration: 0.48 secs
# 01:29:02   speed: 10.49 batch / sec
# 01:29:02   ETA: 1.83 mins
# 01:29:02   max GPU memory: 296.9 MiB
# 01:29:02   ------------------------------
# 01:29:02   average binary cross entropy: 0.201724
# 01:29:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:02   Epoch 38 begin
# 01:29:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:02   Epoch 38 end
# 01:29:02   duration: 0.48 secs
# 01:29:02   speed: 10.40 batch / sec
# 01:29:02   ETA: 1.77 mins
# 01:29:02   max GPU memory: 298.4 MiB
# 01:29:02   ------------------------------
# 01:29:02   average binary cross entropy: 0.206095
# 01:29:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:02   Epoch 39 begin
# 01:29:03   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:03   Epoch 39 end
# 01:29:03   duration: 0.48 secs
# 01:29:03   speed: 10.45 batch / sec
# 01:29:03   ETA: 1.71 mins
# 01:29:03   max GPU memory: 298.5 MiB
# 01:29:03   ------------------------------
# 01:29:03   average binary cross entropy: 0.192843
# 01:29:03   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:03   Epoch 40 begin
# 01:29:03   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:03   binary cross entropy: 0.156226
# 01:29:03   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:03   Epoch 40 end
# 01:29:03   duration: 0.49 secs
# 01:29:03   speed: 10.23 batch / sec
# 01:29:03   ETA: 1.65 mins
# 01:29:03   max GPU memory: 297.1 MiB
# 01:29:03   ------------------------------
# 01:29:03   average binary cross entropy: 0.184982
# 01:29:03   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:03   Epoch 41 begin
# 01:29:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:04   Epoch 41 end
# 01:29:04   duration: 0.65 secs
# 01:29:04   speed: 7.73 batch / sec
# 01:29:04   ETA: 1.60 mins
# 01:29:04   max GPU memory: 297.1 MiB
# 01:29:04   ------------------------------
# 01:29:04   average binary cross entropy: 0.178148
# 01:29:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:04   Epoch 42 begin
# 01:29:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:04   Epoch 42 end
# 01:29:04   duration: 0.48 secs
# 01:29:04   speed: 10.45 batch / sec
# 01:29:04   ETA: 1.55 mins
# 01:29:04   max GPU memory: 296.5 MiB
# 01:29:04   ------------------------------
# 01:29:04   average binary cross entropy: 0.166869
# 01:29:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:04   Epoch 43 begin
# 01:29:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:05   Epoch 43 end
# 01:29:05   duration: 0.47 secs
# 01:29:05   speed: 10.55 batch / sec
# 01:29:05   ETA: 1.50 mins
# 01:29:05   max GPU memory: 299.5 MiB
# 01:29:05   ------------------------------
# 01:29:05   average binary cross entropy: 0.176779
# 01:29:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:05   Epoch 44 begin
# 01:29:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:05   Epoch 44 end
# 01:29:05   duration: 0.48 secs
# 01:29:05   speed: 10.48 batch / sec
# 01:29:05   ETA: 1.45 mins
# 01:29:05   max GPU memory: 296.6 MiB
# 01:29:05   ------------------------------
# 01:29:05   average binary cross entropy: 0.181917
# 01:29:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:05   Epoch 45 begin
# 01:29:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:06   Epoch 45 end
# 01:29:06   duration: 0.48 secs
# 01:29:06   speed: 10.46 batch / sec
# 01:29:06   ETA: 1.40 mins
# 01:29:06   max GPU memory: 296.9 MiB
# 01:29:06   ------------------------------
# 01:29:06   average binary cross entropy: 0.181138
# 01:29:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:06   Epoch 46 begin
# 01:29:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:06   Epoch 46 end
# 01:29:06   duration: 0.48 secs
# 01:29:06   speed: 10.39 batch / sec
# 01:29:06   ETA: 1.35 mins
# 01:29:06   max GPU memory: 297.0 MiB
# 01:29:06   ------------------------------
# 01:29:06   average binary cross entropy: 0.176347
# 01:29:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:06   Epoch 47 begin
# 01:29:07   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:07   Epoch 47 end
# 01:29:07   duration: 0.49 secs
# 01:29:07   speed: 10.19 batch / sec
# 01:29:07   ETA: 1.31 mins
# 01:29:07   max GPU memory: 296.6 MiB
# 01:29:07   ------------------------------
# 01:29:07   average binary cross entropy: 0.174548
# 01:29:07   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:07   Epoch 48 begin
# 01:29:07   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:07   Epoch 48 end
# 01:29:07   duration: 0.48 secs
# 01:29:07   speed: 10.36 batch / sec
# 01:29:07   ETA: 1.26 mins
# 01:29:07   max GPU memory: 300.2 MiB
# 01:29:07   ------------------------------
# 01:29:07   average binary cross entropy: 0.171676
# 01:29:07   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:07   Epoch 49 begin
# 01:29:08   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:08   Epoch 49 end
# 01:29:08   duration: 0.48 secs
# 01:29:08   speed: 10.34 batch / sec
# 01:29:08   ETA: 1.22 mins
# 01:29:08   max GPU memory: 297.0 MiB
# 01:29:08   ------------------------------
# 01:29:08   average binary cross entropy: 0.17337
# 01:29:08   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:08   Epoch 50 begin
# 01:29:08   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:08   Epoch 50 end
# 01:29:08   duration: 0.48 secs
# 01:29:08   speed: 10.42 batch / sec
# 01:29:08   ETA: 1.18 mins
# 01:29:08   max GPU memory: 297.4 MiB
# 01:29:08   ------------------------------
# 01:29:08   average binary cross entropy: 0.160294
# 01:29:08   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:08   Epoch 51 begin
# 01:29:09   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:09   Epoch 51 end
# 01:29:09   duration: 0.48 secs
# 01:29:09   speed: 10.43 batch / sec
# 01:29:09   ETA: 1.14 mins
# 01:29:09   max GPU memory: 296.8 MiB
# 01:29:09   ------------------------------
# 01:29:09   average binary cross entropy: 0.154942
# 01:29:09   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:09   Epoch 52 begin
# 01:29:09   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:09   Epoch 52 end
# 01:29:09   duration: 0.48 secs
# 01:29:09   speed: 10.47 batch / sec
# 01:29:09   ETA: 1.11 mins
# 01:29:09   max GPU memory: 296.5 MiB
# 01:29:09   ------------------------------
# 01:29:09   average binary cross entropy: 0.160363
# 01:29:09   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:09   Epoch 53 begin
# 01:29:10   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:10   Epoch 53 end
# 01:29:10   duration: 0.48 secs
# 01:29:10   speed: 10.48 batch / sec
# 01:29:10   ETA: 1.07 mins
# 01:29:10   max GPU memory: 297.8 MiB
# 01:29:10   ------------------------------
# 01:29:10   average binary cross entropy: 0.154116
# 01:29:10   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:10   Epoch 54 begin
# 01:29:10   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:10   Epoch 54 end
# 01:29:10   duration: 0.48 secs
# 01:29:10   speed: 10.31 batch / sec
# 01:29:10   ETA: 1.03 mins
# 01:29:10   max GPU memory: 297.0 MiB
# 01:29:10   ------------------------------
# 01:29:10   average binary cross entropy: 0.146873
# 01:29:10   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:10   Epoch 55 begin
# 01:29:11   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:11   Epoch 55 end
# 01:29:11   duration: 0.47 secs
# 01:29:11   speed: 10.54 batch / sec
# 01:29:11   ETA: 59.91 secs
# 01:29:11   max GPU memory: 297.1 MiB
# 01:29:11   ------------------------------
# 01:29:11   average binary cross entropy: 0.13683
# 01:29:11   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:11   Epoch 56 begin
# 01:29:11   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:11   Epoch 56 end
# 01:29:11   duration: 0.47 secs
# 01:29:11   speed: 10.57 batch / sec
# 01:29:11   ETA: 57.88 secs
# 01:29:11   max GPU memory: 296.6 MiB
# 01:29:11   ------------------------------
# 01:29:11   average binary cross entropy: 0.135839
# 01:29:11   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:11   Epoch 57 begin
# 01:29:12   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:12   Epoch 57 end
# 01:29:12   duration: 0.50 secs
# 01:29:12   speed: 10.06 batch / sec
# 01:29:12   ETA: 55.92 secs
# 01:29:12   max GPU memory: 297.2 MiB
# 01:29:12   ------------------------------
# 01:29:12   average binary cross entropy: 0.134714
# 01:29:12   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:12   Epoch 58 begin
# 01:29:12   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:12   Epoch 58 end
# 01:29:12   duration: 0.48 secs
# 01:29:12   speed: 10.49 batch / sec
# 01:29:12   ETA: 53.99 secs
# 01:29:12   max GPU memory: 296.8 MiB
# 01:29:12   ------------------------------
# 01:29:12   average binary cross entropy: 0.143857
# 01:29:12   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:12   Epoch 59 begin
# 01:29:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:13   Epoch 59 end
# 01:29:13   duration: 0.48 secs
# 01:29:13   speed: 10.40 batch / sec
# 01:29:13   ETA: 52.12 secs
# 01:29:13   max GPU memory: 297.0 MiB
# 01:29:13   ------------------------------
# 01:29:13   average binary cross entropy: 0.165784
# 01:29:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:13   Epoch 60 begin
# 01:29:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:13   binary cross entropy: 0.106273
# 01:29:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:13   Epoch 60 end
# 01:29:13   duration: 0.49 secs
# 01:29:13   speed: 10.21 batch / sec
# 01:29:13   ETA: 50.30 secs
# 01:29:13   max GPU memory: 298.6 MiB
# 01:29:13   ------------------------------
# 01:29:13   average binary cross entropy: 0.128795
# 01:29:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:13   Epoch 61 begin
# 01:29:14   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:14   Epoch 61 end
# 01:29:14   duration: 0.49 secs
# 01:29:14   speed: 10.14 batch / sec
# 01:29:14   ETA: 48.52 secs
# 01:29:14   max GPU memory: 314.2 MiB
# 01:29:14   ------------------------------
# 01:29:14   average binary cross entropy: 0.133824
# 01:29:14   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:14   Epoch 62 begin
# 01:29:14   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:14   Epoch 62 end
# 01:29:14   duration: 0.47 secs
# 01:29:14   speed: 10.62 batch / sec
# 01:29:14   ETA: 46.77 secs
# 01:29:14   max GPU memory: 296.4 MiB
# 01:29:14   ------------------------------
# 01:29:14   average binary cross entropy: 0.119152
# 01:29:14   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:14   Epoch 63 begin
# 01:29:14   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:14   Epoch 63 end
# 01:29:14   duration: 0.48 secs
# 01:29:14   speed: 10.41 batch / sec
# 01:29:14   ETA: 45.06 secs
# 01:29:14   max GPU memory: 297.1 MiB
# 01:29:14   ------------------------------
# 01:29:14   average binary cross entropy: 0.116834
# 01:29:14   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:14   Epoch 64 begin
# 01:29:15   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:15   Epoch 64 end
# 01:29:15   duration: 0.48 secs
# 01:29:15   speed: 10.41 batch / sec
# 01:29:15   ETA: 43.40 secs
# 01:29:15   max GPU memory: 298.5 MiB
# 01:29:15   ------------------------------
# 01:29:15   average binary cross entropy: 0.125741
# 01:29:15   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:15   Epoch 65 begin
# 01:29:15   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:15   Epoch 65 end
# 01:29:15   duration: 0.47 secs
# 01:29:15   speed: 10.63 batch / sec
# 01:29:15   ETA: 41.76 secs
# 01:29:15   max GPU memory: 296.2 MiB
# 01:29:15   ------------------------------
# 01:29:15   average binary cross entropy: 0.118041
# 01:29:15   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:15   Epoch 66 begin
# 01:29:16   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:16   Epoch 66 end
# 01:29:16   duration: 0.48 secs
# 01:29:16   speed: 10.46 batch / sec
# 01:29:16   ETA: 40.16 secs
# 01:29:16   max GPU memory: 298.4 MiB
# 01:29:16   ------------------------------
# 01:29:16   average binary cross entropy: 0.130518
# 01:29:16   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:16   Epoch 67 begin
# 01:29:16   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:16   Epoch 67 end
# 01:29:16   duration: 0.47 secs
# 01:29:16   speed: 10.59 batch / sec
# 01:29:16   ETA: 38.59 secs
# 01:29:16   max GPU memory: 298.9 MiB
# 01:29:16   ------------------------------
# 01:29:16   average binary cross entropy: 0.118475
# 01:29:16   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:16   Epoch 68 begin
# 01:29:17   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:17   Epoch 68 end
# 01:29:17   duration: 0.48 secs
# 01:29:17   speed: 10.49 batch / sec
# 01:29:17   ETA: 37.06 secs
# 01:29:17   max GPU memory: 296.5 MiB
# 01:29:17   ------------------------------
# 01:29:17   average binary cross entropy: 0.150762
# 01:29:17   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:17   Epoch 69 begin
# 01:29:17   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:17   Epoch 69 end
# 01:29:17   duration: 0.48 secs
# 01:29:17   speed: 10.49 batch / sec
# 01:29:17   ETA: 35.56 secs
# 01:29:17   max GPU memory: 298.0 MiB
# 01:29:17   ------------------------------
# 01:29:17   average binary cross entropy: 0.135738
# 01:29:17   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:17   Epoch 70 begin
# 01:29:18   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:18   Epoch 70 end
# 01:29:18   duration: 0.47 secs
# 01:29:18   speed: 10.61 batch / sec
# 01:29:18   ETA: 34.08 secs
# 01:29:18   max GPU memory: 298.4 MiB
# 01:29:18   ------------------------------
# 01:29:18   average binary cross entropy: 0.133714
# 01:29:18   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:18   Epoch 71 begin
# 01:29:18   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:18   Epoch 71 end
# 01:29:18   duration: 0.47 secs
# 01:29:18   speed: 10.54 batch / sec
# 01:29:18   ETA: 32.63 secs
# 01:29:18   max GPU memory: 297.1 MiB
# 01:29:18   ------------------------------
# 01:29:18   average binary cross entropy: 0.124379
# 01:29:18   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:18   Epoch 72 begin
# 01:29:19   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:19   Epoch 72 end
# 01:29:19   duration: 0.48 secs
# 01:29:19   speed: 10.47 batch / sec
# 01:29:19   ETA: 31.21 secs
# 01:29:19   max GPU memory: 296.6 MiB
# 01:29:19   ------------------------------
# 01:29:19   average binary cross entropy: 0.119484
# 01:29:19   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:19   Epoch 73 begin
# 01:29:19   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:19   Epoch 73 end
# 01:29:19   duration: 0.48 secs
# 01:29:19   speed: 10.46 batch / sec
# 01:29:19   ETA: 29.82 secs
# 01:29:19   max GPU memory: 298.6 MiB
# 01:29:19   ------------------------------
# 01:29:19   average binary cross entropy: 0.105971
# 01:29:19   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:19   Epoch 74 begin
# 01:29:20   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:20   Epoch 74 end
# 01:29:20   duration: 0.48 secs
# 01:29:20   speed: 10.45 batch / sec
# 01:29:20   ETA: 28.45 secs
# 01:29:20   max GPU memory: 298.6 MiB
# 01:29:20   ------------------------------
# 01:29:20   average binary cross entropy: 0.112996
# 01:29:20   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:20   Epoch 75 begin
# 01:29:20   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:20   Epoch 75 end
# 01:29:20   duration: 0.47 secs
# 01:29:20   speed: 10.63 batch / sec
# 01:29:20   ETA: 27.10 secs
# 01:29:20   max GPU memory: 296.9 MiB
# 01:29:20   ------------------------------
# 01:29:20   average binary cross entropy: 0.107385
# 01:29:20   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:20   Epoch 76 begin
# 01:29:21   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:21   Epoch 76 end
# 01:29:21   duration: 0.48 secs
# 01:29:21   speed: 10.52 batch / sec
# 01:29:21   ETA: 25.78 secs
# 01:29:21   max GPU memory: 296.9 MiB
# 01:29:21   ------------------------------
# 01:29:21   average binary cross entropy: 0.100217
# 01:29:21   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:21   Epoch 77 begin
# 01:29:21   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:21   Epoch 77 end
# 01:29:21   duration: 0.48 secs
# 01:29:21   speed: 10.47 batch / sec
# 01:29:21   ETA: 24.47 secs
# 01:29:21   max GPU memory: 302.2 MiB
# 01:29:21   ------------------------------
# 01:29:21   average binary cross entropy: 0.099581
# 01:29:21   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:21   Epoch 78 begin
# 01:29:22   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:22   Epoch 78 end
# 01:29:22   duration: 0.47 secs
# 01:29:22   speed: 10.57 batch / sec
# 01:29:22   ETA: 23.19 secs
# 01:29:22   max GPU memory: 298.9 MiB
# 01:29:22   ------------------------------
# 01:29:22   average binary cross entropy: 0.101805
# 01:29:22   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:22   Epoch 79 begin
# 01:29:22   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:22   Epoch 79 end
# 01:29:22   duration: 0.47 secs
# 01:29:22   speed: 10.54 batch / sec
# 01:29:22   ETA: 21.93 secs
# 01:29:22   max GPU memory: 296.1 MiB
# 01:29:22   ------------------------------
# 01:29:22   average binary cross entropy: 0.102048
# 01:29:22   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:22   Epoch 80 begin
# 01:29:22   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:22   binary cross entropy: 0.091805
# 01:29:23   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:23   Epoch 80 end
# 01:29:23   duration: 0.48 secs
# 01:29:23   speed: 10.40 batch / sec
# 01:29:23   ETA: 20.69 secs
# 01:29:23   max GPU memory: 296.6 MiB
# 01:29:23   ------------------------------
# 01:29:23   average binary cross entropy: 0.0978195
# 01:29:23   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:23   Epoch 81 begin
# 01:29:23   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:23   Epoch 81 end
# 01:29:23   duration: 0.48 secs
# 01:29:23   speed: 10.44 batch / sec
# 01:29:23   ETA: 19.47 secs
# 01:29:23   max GPU memory: 296.7 MiB
# 01:29:23   ------------------------------
# 01:29:23   average binary cross entropy: 0.0966361
# 01:29:23   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:23   Epoch 82 begin
# 01:29:24   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:24   Epoch 82 end
# 01:29:24   duration: 0.48 secs
# 01:29:24   speed: 10.42 batch / sec
# 01:29:24   ETA: 18.26 secs
# 01:29:24   max GPU memory: 297.0 MiB
# 01:29:24   ------------------------------
# 01:29:24   average binary cross entropy: 0.0916446
# 01:29:24   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:24   Epoch 83 begin
# 01:29:24   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:24   Epoch 83 end
# 01:29:24   duration: 0.48 secs
# 01:29:24   speed: 10.40 batch / sec
# 01:29:24   ETA: 17.07 secs
# 01:29:24   max GPU memory: 297.1 MiB
# 01:29:24   ------------------------------
# 01:29:24   average binary cross entropy: 0.0926425
# 01:29:24   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:24   Epoch 84 begin
# 01:29:24   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:24   Epoch 84 end
# 01:29:24   duration: 0.48 secs
# 01:29:24   speed: 10.50 batch / sec
# 01:29:24   ETA: 15.90 secs
# 01:29:24   max GPU memory: 296.6 MiB
# 01:29:25   ------------------------------
# 01:29:25   average binary cross entropy: 0.0905995
# 01:29:25   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:25   Epoch 85 begin
# 01:29:25   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:25   Epoch 85 end
# 01:29:25   duration: 0.48 secs
# 01:29:25   speed: 10.43 batch / sec
# 01:29:25   ETA: 14.75 secs
# 01:29:25   max GPU memory: 298.8 MiB
# 01:29:25   ------------------------------
# 01:29:25   average binary cross entropy: 0.0976857
# 01:29:25   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:25   Epoch 86 begin
# 01:29:25   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:25   Epoch 86 end
# 01:29:25   duration: 0.48 secs
# 01:29:25   speed: 10.44 batch / sec
# 01:29:25   ETA: 13.61 secs
# 01:29:25   max GPU memory: 297.0 MiB
# 01:29:25   ------------------------------
# 01:29:25   average binary cross entropy: 0.0957928
# 01:29:25   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:25   Epoch 87 begin
# 01:29:26   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:26   Epoch 87 end
# 01:29:26   duration: 0.48 secs
# 01:29:26   speed: 10.52 batch / sec
# 01:29:26   ETA: 12.48 secs
# 01:29:26   max GPU memory: 298.8 MiB
# 01:29:26   ------------------------------
# 01:29:26   average binary cross entropy: 0.0894858
# 01:29:26   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:26   Epoch 88 begin
# 01:29:26   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:26   Epoch 88 end
# 01:29:26   duration: 0.48 secs
# 01:29:26   speed: 10.38 batch / sec
# 01:29:26   ETA: 11.37 secs
# 01:29:26   max GPU memory: 297.9 MiB
# 01:29:26   ------------------------------
# 01:29:26   average binary cross entropy: 0.0856803
# 01:29:26   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:26   Epoch 89 begin
# 01:29:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:27   Epoch 89 end
# 01:29:27   duration: 0.48 secs
# 01:29:27   speed: 10.37 batch / sec
# 01:29:27   ETA: 10.28 secs
# 01:29:27   max GPU memory: 297.0 MiB
# 01:29:27   ------------------------------
# 01:29:27   average binary cross entropy: 0.0821174
# 01:29:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:27   Epoch 90 begin
# 01:29:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:27   Epoch 90 end
# 01:29:27   duration: 0.60 secs
# 01:29:27   speed: 8.37 batch / sec
# 01:29:27   ETA: 9.21 secs
# 01:29:27   max GPU memory: 296.3 MiB
# 01:29:27   ------------------------------
# 01:29:27   average binary cross entropy: 0.0819081
# 01:29:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:28   Epoch 91 begin
# 01:29:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:28   Epoch 91 end
# 01:29:28   duration: 0.54 secs
# 01:29:28   speed: 9.25 batch / sec
# 01:29:28   ETA: 8.14 secs
# 01:29:28   max GPU memory: 296.8 MiB
# 01:29:28   ------------------------------
# 01:29:28   average binary cross entropy: 0.0835649
# 01:29:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:28   Epoch 92 begin
# 01:29:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:29   Epoch 92 end
# 01:29:29   duration: 0.55 secs
# 01:29:29   speed: 9.03 batch / sec
# 01:29:29   ETA: 7.09 secs
# 01:29:29   max GPU memory: 298.1 MiB
# 01:29:29   ------------------------------
# 01:29:29   average binary cross entropy: 0.0730345
# 01:29:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:29   Epoch 93 begin
# 01:29:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:29   Epoch 93 end
# 01:29:29   duration: 0.62 secs
# 01:29:29   speed: 8.10 batch / sec
# 01:29:29   ETA: 6.05 secs
# 01:29:29   max GPU memory: 296.8 MiB
# 01:29:29   ------------------------------
# 01:29:29   average binary cross entropy: 0.0751974
# 01:29:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:29   Epoch 94 begin
# 01:29:30   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:30   Epoch 94 end
# 01:29:30   duration: 0.48 secs
# 01:29:30   speed: 10.44 batch / sec
# 01:29:30   ETA: 5.02 secs
# 01:29:30   max GPU memory: 301.8 MiB
# 01:29:30   ------------------------------
# 01:29:30   average binary cross entropy: 0.0743946
# 01:29:30   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:30   Epoch 95 begin
# 01:29:30   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:30   Epoch 95 end
# 01:29:30   duration: 0.48 secs
# 01:29:30   speed: 10.38 batch / sec
# 01:29:30   ETA: 3.99 secs
# 01:29:30   max GPU memory: 297.0 MiB
# 01:29:30   ------------------------------
# 01:29:30   average binary cross entropy: 0.0761294
# 01:29:30   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:30   Epoch 96 begin
# 01:29:31   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:31   Epoch 96 end
# 01:29:31   duration: 0.47 secs
# 01:29:31   speed: 10.64 batch / sec
# 01:29:31   ETA: 2.98 secs
# 01:29:31   max GPU memory: 299.7 MiB
# 01:29:31   ------------------------------
# 01:29:31   average binary cross entropy: 0.0728957
# 01:29:31   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:31   Epoch 97 begin
# 01:29:31   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:31   Epoch 97 end
# 01:29:31   duration: 0.48 secs
# 01:29:31   speed: 10.45 batch / sec
# 01:29:31   ETA: 1.97 secs
# 01:29:31   max GPU memory: 296.9 MiB
# 01:29:31   ------------------------------
# 01:29:31   average binary cross entropy: 0.0732534
# 01:29:31   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:31   Epoch 98 begin
# 01:29:32   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:32   Epoch 98 end
# 01:29:32   duration: 0.47 secs
# 01:29:32   speed: 10.55 batch / sec
# 01:29:32   ETA: 0.98 secs
# 01:29:32   max GPU memory: 298.8 MiB
# 01:29:32   ------------------------------
# 01:29:32   average binary cross entropy: 0.0671356
# 01:29:32   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:32   Epoch 99 begin
# 01:29:32   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:32   Epoch 99 end
# 01:29:32   duration: 0.47 secs
# 01:29:32   speed: 10.63 batch / sec
# 01:29:32   ETA: 0.00 secs
# 01:29:32   max GPU memory: 297.1 MiB
# 01:29:32   ------------------------------
# 01:29:32   average binary cross entropy: 0.0718927
# 01:29:32   Evaluate on valid
# 01:29:32   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 01:29:32   auprc [Class]: 0.890468
# 01:29:32   auroc [Class]: 0.608425
# {'auprc [Class]': tensor(0.8905, device='cuda:0'),
#  'auroc [Class]': tensor(0.6084, device='cuda:0')}
